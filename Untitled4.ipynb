# %% [markdown]
# <a href="https://colab.research.google.com/github/HappySingh0102/PCC_PythonCrashCourse/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filename = 'myfile.txt'
simple_filename = filename.removesuffix('.txt')
print(filename)
print(simple_filename)
